# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import cv2
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
train_dataset_path = "/Users/pranayrajsarap/Spoken Language Processing/December_2021/lisnen_segmented_working_data/train"

# %%
val_dataset_path = "/Users/pranayrajsarap/Spoken Language Processing/December_2021/lisnen_segmented_working_data/val"

# %%
test_dataset_path = "/Users/pranayrajsarap/Spoken Language Processing/December_2021/lisnen_segmented_working_data/test"

# %%
IMG_WIDTH = 227
IMG_HEIGHT = 227
BATCH_SIZE = 32

# %% [markdown]
# # Data Augmentation

# %%
train_datagen = ImageDataGenerator(rescale=1.0/255,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   fill_mode='nearest')

train_generator = train_datagen.flow_from_directory(train_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 1337 images belonging to 4 classes.

# %%
valid_datagen = ImageDataGenerator(rescale=1.0/255,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   fill_mode='nearest')

valid_generator = valid_datagen.flow_from_directory(val_dataset_path,
                                                   target_size=(IMG_WIDTH, IMG_HEIGHT),
                                                   batch_size=BATCH_SIZE,
                                                   class_mode='categorical',
                                                   shuffle=True)
# Out:
# Found 165 images belonging to 4 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1.0/255)

test_generator = test_datagen.flow_from_directory(test_dataset_path,
                                                 shuffle=False,
                                                 batch_size=BATCH_SIZE,
                                                 target_size = (IMG_WIDTH, IMG_HEIGHT),
                                                 class_mode='categorical')
# Out:
# Found 171 images belonging to 4 classes.

# %%
labels = {value: key for key, value in train_generator.class_indices.items()}

print("Label Mappings for classed present in the training and validation datasets\n")
for key,value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label Mappings for classed present in the training and validation datasets
#
# 0 : Baby_Cry_Melspectrograms
# 1 : Door_Bell_Melspectrograms
# 2 : Door_Knock_Melspectrograms
# 3 : Fire_Alarm_Melspectrograms

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(15,12))
idx = 0
for i in range(2):
    for j in range(5):
        label = labels[np.argmax(train_generator[0][1][idx])]
        ax[i, j].set_title(f"{label} \t")
        ax[i, j].imshow(train_generator[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx +=1

plt.tight_layout()
plt.suptitle("Sample Training Images", fontsize=21)
plt.show()

# %%
# from sklearn.model_selection import train_test_split
# import keras

# dcase_model = Sequential()
# dcase_model.add(Conv2D(16, 7, padding='same',input_shape=(IMG_WIDTH,IMG_HEIGHT,3)))  # X_train.shape[1] = No. of Columns
# dcase_model.add(BatchNormalization())
# dcase_model.add(Activation('relu'))
# dcase_model.add(Conv2D(16,7,padding='same'))
# dcase_model.add(BatchNormalization())
# dcase_model.add(Activation('relu'))
# dcase_model.add(MaxPooling2D(pool_size=(8,8)))
# dcase_model.add(Dropout(0.3))
# dcase_model.add(Conv2D(32,7,padding='same'))
# dcase_model.add(BatchNormalization())
# dcase_model.add(Activation('relu'))
# dcase_model.add(MaxPooling2D(pool_size=(4,4)))
# dcase_model.add(Dropout(0.3))
# dcase_model.add(Flatten())
# dcase_model.add(Dense(100,activation='relu'))
# dcase_model.add(Dropout(0.3))
# dcase_model.add(Dense(4))
# dcase_model.add(Activation('softmax'))
# # opt = keras.optimizers.SGD(lr=0.0001, momentum=0.0, decay=0.0, nesterov=False)
# opt = keras.optimizers.Adam(lr=0.0001)
# #opt = keras.optimizers.RMSprop(lr=0.001, decay=1e-6)
# dcase_model.summary()

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Bidirectional, GRU
from keras.layers import Flatten, Dense, Reshape

# Define the model
dcase_model = Sequential()

# Convolutional layers
dcase_model.add(Conv2D(64, (7, 7), strides=(2, 1), padding='same', activation='relu', input_shape=(IMG_WIDTH,IMG_HEIGHT,3)))
dcase_model.add(MaxPooling2D((3, 3), strides=(2, 2)))

dcase_model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
dcase_model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))

dcase_model.add(Conv2D(128, (3, 3), strides=(2, 2), padding='same', activation='relu'))
dcase_model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))

dcase_model.add(AveragePooling2D((1, 3), strides=(1, 2)))

dcase_model.add(Flatten())
dcase_model.add(Dense(128, activation='relu'))
dcase_model.add(Reshape((-1, 128)))

# Bi-GRU layer
dcase_model.add(Bidirectional(GRU(units=128, return_sequences=True)))

# Flatten and dense layers
dcase_model.add(Flatten())
dcase_model.add(Dense(128, activation='relu'))
dcase_model.add(Dense(4, activation='softmax'))

# Compile the model
dcase_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
dcase_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 114, 227, 64)      9472
#
#  max_pooling2d (MaxPooling2  (None, 56, 113, 64)       0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 56, 113, 64)       36928
#
#  conv2d_2 (Conv2D)           (None, 56, 113, 64)       36928
#
#  conv2d_3 (Conv2D)           (None, 28, 57, 128)       73856
#
#  conv2d_4 (Conv2D)           (None, 28, 57, 128)       147584
#
#  average_pooling2d (Average  (None, 28, 28, 128)       0
#  Pooling2D)
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 128)               12845184
#
#  reshape (Reshape)           (None, 1, 128)            0
#
#  bidirectional (Bidirection  (None, 1, 256)            198144
#  al)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 13381508 (51.05 MB)
# Trainable params: 13381508 (51.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import keras
opt = keras.optimizers.Adam(lr=0.0001)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
from tensorflow.keras import metrics
dcase_model.compile(loss='categorical_crossentropy', optimizer=opt,metrics=['accuracy'])#,metrics.Precision(),metrics.Recall()])
dcase_model_history=dcase_model.fit(train_generator,
                                    batch_size=16,
                                    epochs=100,
                                    validation_data=valid_generator)
                                      #)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 37s 843ms/step - loss: 1.0748 - accuracy: 0.5475 - val_loss: 1.0530 - val_accuracy: 0.5818
# Epoch 2/100
# 42/42 [==============================] - 35s 833ms/step - loss: 0.6420 - accuracy: 0.7509 - val_loss: 0.6915 - val_accuracy: 0.7636
# Epoch 3/100
# 42/42 [==============================] - 35s 830ms/step - loss: 0.5165 - accuracy: 0.7966 - val_loss: 0.5060 - val_accuracy: 0.7879
# Epoch 4/100
# 42/42 [==============================] - 35s 826ms/step - loss: 0.4932 - accuracy: 0.8033 - val_loss: 0.6197 - val_accuracy: 0.7818
# Epoch 5/100
# 42/42 [==============================] - 35s 827ms/step - loss: 0.4652 - accuracy: 0.8212 - val_loss: 0.4914 - val_accuracy: 0.7818
# Epoch 6/100
# 42/42 [==============================] - 36s 851ms/step - loss: 0.3736 - accuracy: 0.8512 - val_loss: 0.4882 - val_accuracy: 0.7879
# Epoch 7/100
# 42/42 [==============================] - 35s 822ms/step - loss: 0.3529 - accuracy: 0.8669 - val_loss: 0.4430 - val_accuracy: 0.8424
# Epoch 8/100
# 42/42 [==============================] - 35s 826ms/step - loss: 0.3438 - accuracy: 0.8743 - val_loss: 0.4957 - val_accuracy: 0.8182
# Epoch 9/100
# 42/42 [==============================] - 36s 863ms/step - loss: 0.3436 - accuracy: 0.8714 - val_loss: 0.3379 - val_accuracy: 0.8848
# Epoch 10/100
# 42/42 [==============================] - 35s 826ms/step - loss: 0.2951 - accuracy: 0.8908 - val_loss: 0.3036 - val_accuracy: 0.8909
# Epoch 11/100
# 42/42 [==============================] - 35s 821ms/step - loss: 0.2927 - accuracy: 0.8893 - val_loss: 0.3833 - val_accuracy: 0.8545
# Epoch 12/100
# 42/42 [==============================] - 34s 816ms/step - loss: 0.2480 - accuracy: 0.9073 - val_loss: 0.3304 - val_accuracy: 0.9091
# Epoch 13/100
# 42/42 [==============================] - 34s 817ms/step - loss: 0.2716 - accuracy: 0.9050 - val_loss: 0.2912 - val_accuracy: 0.9152
# Epoch 14/100
# 42/42 [==============================] - 35s 817ms/step - loss: 0.2244 - accuracy: 0.9222 - val_loss: 0.3835 - val_accuracy: 0.8848
# Epoch 15/100
# 42/42 [==============================] - 35s 819ms/step - loss: 0.2420 - accuracy: 0.9132 - val_loss: 0.2602 - val_accuracy: 0.9030
# Epoch 16/100
# 42/42 [==============================] - 35s 818ms/step - loss: 0.2291 - accuracy: 0.9147 - val_loss: 0.4175 - val_accuracy: 0.8424
# Epoch 17/100
# 42/42 [==============================] - 35s 823ms/step - loss: 0.2155 - accuracy: 0.9222 - val_loss: 0.3141 - val_accuracy: 0.8970
# Epoch 18/100
# 42/42 [==============================] - 35s 820ms/step - loss: 0.2119 - accuracy: 0.9215 - val_loss: 0.2343 - val_accuracy: 0.9030
# Epoch 19/100
# 42/42 [==============================] - 35s 822ms/step - loss: 0
100
# 42/42 [==============================] - 35s 822ms/step - loss: 0.0918 - accuracy: 0.9663 - val_loss: 0.2097 - val_accuracy: 0.9212
# Epoch 66/100
# 42/42 [==============================] - 34s 815ms/step - loss: 0.0707 - accuracy: 0.9708 - val_loss: 0.2853 - val_accuracy: 0.9091
# Epoch 67/100
# 42/42 [==============================] - 34s 815ms/step - loss: 0.0935 - accuracy: 0.9693 - val_loss: 0.1649 - val_accuracy: 0.9576
# Epoch 68/100
# 42/42 [==============================] - 34s 815ms/step - loss: 0.0635 - accuracy: 0.9813 - val_loss: 0.2238 - val_accuracy: 0.9515
# Epoch 69/100
# 42/42 [==============================] - 35s 818ms/step - loss: 0.0802 - accuracy: 0.9723 - val_loss: 0.3912 - val_accuracy: 0.9152
# Epoch 70/100
# 42/42 [==============================] - 34s 816ms/step - loss: 0.0933 - accuracy: 0.9641 - val_loss: 0.1924 - val_accuracy: 0.9515
# Epoch 71/100
# 42/42 [==============================] - 35s 820ms/step - loss: 0.0700 - accuracy: 0.9753 - val_loss: 0.3083 - val_accuracy: 0.9333
# Epoch 72/100
# 42/42 [==============================] - 35s 822ms/step - loss: 0.1019 - accuracy: 0.9686 - val_loss: 0.2205 - val_accuracy: 0.9030
# Epoch 73/100
# 42/42 [==============================] - 35s 819ms/step - loss: 0.1209 - accuracy: 0.9559 - val_loss: 0.2578 - val_accuracy: 0.9091
# Epoch 74/100
# 42/42 [==============================] - 35s 821ms/step - loss: 0.0908 - accuracy: 0.9663 - val_loss: 0.2417 - val_accuracy: 0.9273
# Epoch 75/100
# 42/42 [==============================] - 34s 817ms/step - loss: 0.0957 - accuracy: 0.9686 - val_loss: 0.1955 - val_accuracy: 0.9333
# Epoch 76/100
# 42/42 [==============================] - 35s 818ms/step - loss: 0.0961 - accuracy: 0.9663 - val_loss: 0.3881 - val_accuracy: 0.9091
# Epoch 77/100
# 42/42 [==============================] - 35s 838ms/step - loss: 0.1124 - accuracy: 0.9663 - val_loss: 0.3574 - val_accuracy: 0.9091
# Epoch 78/100
# 42/42 [==============================] - 2856s 70s/step - loss: 0.1282 - accuracy: 0.9514 - val_loss: 0.2167 - val_accuracy: 0.9152
# Epoch 79/100
# 42/42 [==============================] - 6275s 153s/step - loss: 0.0920 - accuracy: 0.9641 - val_loss: 0.2467 - val_accuracy: 0.9091
# Epoch 80/100
# 42/42 [==============================] - 5450s 133s/step - loss: 0.0827 - accuracy: 0.9701 - val_loss: 0.1892 - val_accuracy: 0.9515
# Epoch 81/100
# 42/42 [==============================] - 5530s 135s/step - loss: 0.0835 - accuracy: 0.9671 - val_loss: 0.2698 - val_accuracy: 0.9273
# Epoch 82/100
# 42/42 [==============================] - 3995s 97s/step - loss: 0.0546 - accuracy: 0.9798 - val_loss: 0.2042 - val_accuracy: 0.9333
# Epoch 83/100
# 42/42 [==============================] - 36s 847ms/step - loss: 0.0638 - accuracy: 0.9768 - val_loss: 0.1777 - val_accuracy: 0.9273
# Epoch 84/100
# 42/42 [==============================] - 34s 816ms/step - loss: 0.0840 - accuracy: 0.9723 - val_loss: 0.1989 - val_accuracy: 0.9455
# Epoch 85/100
# 42/42 [==============================] - 34s 816ms/step - loss: 0.0823 - accuracy: 0.9746 - val_loss: 0.2033 - val_accuracy: 0.9515
# Epoch 86/100
# 42/42 [==============================] - 35s 832ms/step - loss: 0.0833 - accuracy: 0.9791 - val_loss: 0.2313 - val_accuracy: 0.9394
# Epoch 87/100
# 42/42 [==============================] - 36s 843ms/step - loss: 0.0780 - accuracy: 0.9716 - val_loss: 0.2095 - val_accuracy: 0.9515
# Epoch 88/100
# 42/42 [==============================] - 35s 833ms/step - loss: 0.0753 - accuracy: 0.9693 - val_loss: 0.2271 - val_accuracy: 0.9152
# Epoch 89/100
# 42/42 [==============================] - 35s 819ms/step - loss: 0.1207 - accuracy: 0.9574 - val_loss: 0.2051 - val_accuracy: 0.9030
# Epoch 90/100
# 42/42 [==============================] - 34s 815ms/step - loss: 0.1213 - accuracy: 0.9581 - val_loss: 0.1259 - val_accuracy: 0.9455
# Epoch 91/100
# 42/42 [==============================] - 35s 818ms/step - loss: 0.1030 - accuracy: 0.9596 - val_loss: 0.1787 - val_accuracy: 0.9333
# Epoch 92/100
# 42/42 [==============================] - 37s 870ms/step - loss: 0.0858 - accuracy: 0.9701 - val_loss: 0.1853 - val_accuracy: 0.9455
# Epoch 93/100
# 42/42 [==============================] - 36s 852ms/step - loss: 0.0936 - accuracy: 0.9626 - val_loss: 0.1967 - val_accuracy: 0.9455
# Epoch 94/100
# 42/42 [==============================] - 36s 852ms/step - loss: 0.0639 - accuracy: 0.9783 - val_loss: 0.1585 - val_accuracy: 0.9576
# Epoch 95/100
# 42/42 [==============================] - 36s 843ms/step - loss: 0.0620 - accuracy: 0.9813 - val_loss: 0.2276 - val_accuracy: 0.9030
# Epoch 96/100
# 42/42 [==============================] - 35s 818ms/step - loss: 0.1169 - accuracy: 0.9574 - val_loss: 0.1749 - val_accuracy: 0.9515
# Epoch 97/100
# 42/42 [==============================] - 34s 817ms/step - loss: 0.0946 - accuracy: 0.9626 - val_loss: 0.3395 - val_accuracy: 0.8970
# Epoch 98/100
# 42/42 [==============================] - 34s 814ms/step - loss: 0.1153 - accuracy: 0.9626 - val_loss: 0.1596 - val_accuracy: 0.9515
# Epoch 99/100
# 42/42 [==============================] - 34s 816ms/step - loss: 0.0752 - accuracy: 0.9716 - val_loss: 0.1988 - val_accuracy: 0.9455
# Epoch 100/100
# 42/42 [==============================] - 34s 814ms/step - loss: 0.0965 - accuracy: 0.9693 - val_loss: 0.1596 - val_accuracy: 0.9394

# %%
plt.plot(dcase_model_history.history['loss'])
plt.plot(dcase_model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(dcase_model_history.history['accuracy'])
plt.plot(dcase_model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
predictions = dcase_model.predict(test_generator)
# Out:
# 6/6 [==============================] - 1s 197ms/step

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(5):
        predicted_label = labels[np.argmax(predictions[idx])]
        ax[i, j].set_title(f"{predicted_label}")
        ax[i, j].imshow(test_generator[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
test_loss, test_accuracy = dcase_model.evaluate(test_generator, batch_size=BATCH_SIZE)
# Out:
# 6/6 [==============================] - 1s 196ms/step - loss: 0.0836 - accuracy: 0.9708

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.08358964323997498
# Test Accuracy: 0.9707602262496948

# %% [markdown]
# # Confusion Matrix

# %%
y_pred = np.argmax(predictions, axis=1)
y_true = test_generator.classes

# %%
# cf_mtx = confusion_matrix(y_true, y_pred)

# group_counts = ["{0:0.0f}".format(value) for value in cf_mtx.flatten()]
# group_percentages = ["{0:.2%}".format(value) for value in cf_mtx.flatten()/np.sum(cf_mtx)]
# box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
# box_labels = np.asarray(box_labels).reshape(6, 6)

# plt.figure(figsize = (12, 10))
# sns.heatmap(cf_mtx, xticklabels=labels.values(), yticklabels=labels.values(),
#            cmap="YlGnBu", fmt="", annot=box_labels)
# plt.xlabel('Predicted Classes')
# plt.ylabel('True Classes')
# plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#                             precision    recall  f1-score   support
#
#   Baby_Cry_Melspectrograms       1.00      0.98      0.99        55
#  Door_Bell_Melspectrograms       0.93      0.97      0.95        29
# Door_Knock_Melspectrograms       0.98      1.00      0.99        44
# Fire_Alarm_Melspectrograms       0.95      0.93      0.94        43
#
#                   accuracy                           0.97       171
#                  macro avg       0.97      0.97      0.97       171
#               weighted avg       0.97      0.97      0.97       171

# %% [markdown]
# # Wrong Predictions

# %%
errors = (y_true - y_pred != 0)
y_true_errors = y_true[errors]
y_pred_errors = y_pred[errors]

# %%
test_images = test_generator.filenames
test_img = np.asarray(test_images)[errors]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(20, 15))
idx = 0

for i in range(2):
    for j in range(5):
        idx = np.random.randint(0, len(test_img))
        true_index = y_true_errors[idx]
        true_label = labels[true_index]
        predicted_index = y_pred_errors[idx]
        predicted_label = labels[predicted_index]
        ax[i, j].set_title(f"True Label: {true_label} \n Predicted Label: {predicted_label}")
        img_path = os.path.join(test_dataset_path, test_img[idx])
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        ax[i, j].imshow(img)
        ax[i, j].axis("off")

plt.tight_layout()
plt.suptitle('Wrong Predictions made on test set', fontsize=25)
plt.show()

# %% [markdown]
# # Change file Names using Python

# %%
#Baby Cry Test files renaming
# import os

# count = 1
# folder_path = "/Users/pranayrajsarap/Spoken Language Processing/December_2021/lisnen_segmented_working_data/test/Baby_Cry_Melspectrograms"

# for file in os.listdir(folder_path):
#     # Check if the file is a regular file (not a directory)
#     if os.path.isfile(os.path.join(folder_path, file)):
#         # Create the new file name with the count prefix
#         new_name = f'btest-{count}.png'
#         # Join the folder path with the file name to get full paths
#         old_path = os.path.join(folder_path, file)
#         new_path = os.path.join(folder_path, new_name)
#         # Rename the file
#         os.rename(old_path, new_path)
#         # Increment count for the next file
#         count += 1

# Door Knock Test files renaming

# import os

# count = 1
# folder_path = "/Users/pranayrajsarap/Spoken Language Processing/December_2021/lisnen_segmented_working_data/test/Door_Knock_Melspectrograms"

# for file in os.listdir(folder_path):
#     # Check if the file is a regular file (not a directory)
#     if os.path.isfile(os.path.join(folder_path, file)):
#         # Create the new file name with the count prefix
#         new_name = f'dktest-{count}.png'
#         # Join the folder path with the file name to get full paths
#         old_path = os.path.join(folder_path, file)
#         new_path = os.path.join(folder_path, new_name)
#         # Rename the file
#         os.rename(old_path, new_path)
#         # Increment count for the next file
#         count += 1

# Door bell Test files renaming
# import os

# count = 1
# folder_path = "/Users/pranayrajsarap/Spoken Language Processing/December_2021/lisnen_segmented_working_data/test/Door_Bell_Melspectrograms"

# for file in os.listdir(folder_path):
#     # Check if the file is a regular file (not a directory)
#     if os.path.isfile(os.path.join(folder_path, file)):
#         # Create the new file name with the count prefix
#         new_name = f'dbtest-{count}.png'
#         # Join the folder path with the file name to get full paths
#         old_path = os.path.join(folder_path, file)
#         new_path = os.path.join(folder_path, new_name)
#         # Rename the file
#         os.rename(old_path, new_path)
#         # Increment count for the next file
#         count += 1

# Fire Alarm Test files remaining
# import os

# count = 1
# folder_path = "/Users/pranayrajsarap/Spoken Language Processing/December_2021/lisnen_segmented_working_data/test/Fire_Alarm_Melspectrograms"

# for file in os.listdir(folder_path):
#     # Check if the file is a regular file (not a directory)
#     if os.path.isfile(os.path.join(folder_path, file)):
#         # Create the new file name with the count prefix
#         new_name = f'fatest-{count}.png'
#         # Join the folder path with the file name to get full paths
#         old_path = os.path.join(folder_path, file)
#         new_path = os.path.join(folder_path, new_name)
#         # Rename the file
#         os.rename(old_path, new_path)
#         # Increment count for the next file
#         count += 1

# %%
# pip install split-folders

# %% [markdown]
# # Split images into train test validation

# %%
# import splitfolders
# splitfolders.ratio(train_dataset_path, output="/Users/pranayrajsarap/Spoken Language Processing/December_2021/lisnen_segmented_working_data/validation_data", seed=1337, ratio=(.8, 0.1,0.1))
